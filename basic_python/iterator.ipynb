# %%
import pandas as pd
import json

scr = {"props":
    {"pageProps":
        {"initialState":
            {"auth":
                {"isLoggedIn":False,"user":{},"isInitialCheckDone":False},
                "init":
                    {"categories":
                        {"62cd958353f5fe61566b9ae4":
                            {"title":"DATA SCIENCE",
                                "subCategories":
                                    {"62cd959d53f5fe14766b9ae5":{"title":"FULL STACK DATA SCIENCE","id":"62cd959d53f5fe14766b9ae5"},
                                    
                                    "62cd95a953f5fe3dc56b9ae6":{"title":"PYTHON","id":"62cd95a953f5fe3dc56b9ae6"},
                                    
                                    "62cd95b453f5fe0a5c6b9ae7":{"title":"PYTHON PROJECT","id":"62cd95b453f5fe0a5c6b9ae7"},
                                    
                                    "62cd95be53f5fe3b956b9ae8":{"title":"PYTHON INTERVIEW","id":"62cd95be53f5fe3b956b9ae8"},
                                    
                                    "62cd95c753f5fe3cc16b9ae9":{"title":"STATS","id":"62cd95c753f5fe3cc16b9ae9"},
                                    
                                    "62cd969753f5fe6d666b9afa":{"title":"MLOPS PROJECT","id":"62cd969753f5fe6d666b9afa"},
                                    
                                    "62cd96a053f5fe55126b9afb":{"title":"MLOPS INTERVIEW PREPARATION","id":"62cd96a053f5fe55126b9afb"}
                                }
                            },
                                    
                        "62cd96ce53f5fe49c46b9afc":
                            {"title":"BIG DATA",
                                "subCategories":
                                    {"62cd971353f5fe38df6b9afd":{"title":"BIG DATA MASTERS","id":"62cd971353f5fe38df6b9afd"},

                                        "62cd972153f5fe08c46b9afe":{"title":"TECH STACK","id":"62cd972153f5fe08c46b9afe"},
                                    }
                            }
                        }
                    }
            }
        }
    }
}

categories_df = pd.DataFrame(scr["props"]["pageProps"]["initialState"]["init"]["categories"],index=['title','subCategories'])
categories_df
# Out:
#                                         62cd958353f5fe61566b9ae4  \
# title                                               DATA SCIENCE
# subCategories  {'62cd959d53f5fe14766b9ae5': {'title': 'FULL S...
#
#                                         62cd96ce53f5fe49c46b9afc
# title                                                   BIG DATA
# subCategories  {'62cd971353f5fe38df6b9afd': {'title': 'BIG DA...

# %%
details = {"Face Swap Application":
{
                     "_id":"639185a7afd9f642649cfc9e",
                     "platformType":"main",
                     "tags":[
                        
                     ],
                     "labPlans":[
                        
                     ],
                     "description":"In this project, we will learn about how to use dlib facial landmark detector to extract the facial features Create the mask using the convex hull of the points extracted. Replace the mask of two images and do a seamless cloning of the image to blend in the color grade.",
                     "mode":"self-paced",
                     "seo":{
                        "keywords":"Face Swap Application"
                     },
                     "batches":[
                        
                     ],
                     "createdAt":"2022-12-08T06:35:19.878Z",
                     "img":"639185a7afd9f642649cfc9e.jpg",
                     "categoryId":"62cd966b53f5feb5986b9af5",
                     "classTimings":{
                        "startDate":"3rd Jan'23",
                        "timings":"Flexible"
                     },
                     "courseMeta":[
                        {
                           "instructors":[
                              "62221167760e3e671af81a65"
                           ],
                           "overview":{
                              "learn":[
                                 "Real Time Project",
                                 "Python",
                                 "Open-CV",
                                 "dlib",
                                 "Image handling in Python"
                              ],
                              "requirements":[
                                 "System with minimum i3 processor or better",
                                 "At least 4 GB of RAM",
                                 "Working internet connection",
                                 "Dedication to learn"
                              ],
                              "features":[
                                 "Do Everything In Industry Grade Lab",
                                 "Learn As Per Your Timeline",
                                 "Hands-On Industry Real-Time Projects.",
                                 "Self Paced Learning",
                                 "Dashboard Access"
                              ],
                              "language":"english"
                           }
                        }
                     ],
                     "instructorsDetails":[
                        {
                           "_id":"62221167760e3e671af81a65",
                           "name":"Bharath J P V ",
                           "description":"Enthusiast Data Scientist with a strong background in Mathematics and Statistics. Completed My Master in Statistics. Have experience teaching Mathematics and Statistics for more than a year. I thought for more than 1000 students and helped them make their careers in their respective fields. I believe in \"we rise by lifting others\". Following this principle, I hope to make your life easier.",
                           "img":{
                              "source":"bucket",
                              "link":"62221167760e3e671af81a65.jpg"
                           }
                        }
                     ],
                     "courseInOneNeuron":{
                        "bundleName":"Data science Projects Neuron",
                        "bundleId":"638f22402f9fa1e3299fc156"
                     },
                     "pricing":{
                        "IN":"15000",
                        "US":"200",
                        "discount":0,
                        "isFree":False
                     }
                  },
                  "Full Stack Data Science Nov'21 Tech Neuron":{
                     "_id":"6389b7ff41896d32c199d378",
                     "platformType":"main",
                     "tags":[
                        
                     ],
                     "labPlans":[
                        
                     ],
                     "description":"This is a full stack data science self-paced course with recordings of  live mentor-led classes and a full-time one-year internship provided by iNeuron intelligence private limited, where you will learn all the stack required to work in the data science, data analytics, and big data industries, including machine learning operations and cloud infrastructure, as well as real-time industry project and product development with the iNeuron product development team, and you will contribute on various levels.",
                     "mode":"self-paced",
                     "seo":{
                        "keywords":"Full Stack Data Science Nov'21 Tech Neuron"
                     },
                     "batches":[
                        
                     ],
                     "createdAt":"2022-12-02T08:32:02.162Z",
                     "img":"6389b7ff41896d32c199d378.jpg",
                     "categoryId":"62cd959d53f5fe14766b9ae5",
                     "classTimings":{
                        
                     },
                     "courseMeta":[
                        {
                           "instructors":[
                              "619370a59db36f163876b413",
                              "618929e26e59b248b8c04aa6",
                              "6222165b760e3ef701f81a6f"
                           ],
                           "overview":{
                              "learn":[
                                 "Python",
                                 "Stats",
                                 "Machine learning",
                                 "Deep learning",
                                 "Computer vision",
                                 "Natural language processing",
                                 "Data analytics",
                                 "Big data",
                                 "Architecture",
                                 "Databases"
                              ],
                              "requirements":[
                                 "System with minimum i3 processor or better",
                                 "At least 4 GB of RAM",
                                 "Working internet connection",
                                 "Dedication to learn"
                              ],
                              "features":[
                                 "Full stack Data Science Recorded Lectures",
                                 "One year of internship Anytime",
                                 "Online Instructor-led learning: Live teaching by instructors",
                                 "56 + hands-on industry real-time projects.",
                                 "500 hours live interactive classes.",
                                 "Lifetime Dashboard access",
                                 "Assignment in all the module"
                              ],
                              "language":"english"
                           }
                        }
                     ],
                     "instructorsDetails":[
                        {
                           "_id":"618929e26e59b248b8c04aa6",
                           "name":"krish naik",
                           "social":{
                              "linkedin":"https://www.linkedin.com/in/naikkrish/",
                              "instagram":"https://www.instagram.com/krishnaik06",
                              "facebook":"https://www.facebook.com/krishnaik06",
                              "youtube":"https://www.youtube.com/user/krishnaik06",
                              "github":"https://github.com/krishnaik06"
                           },
                           "img":{
                              "source":"bucket",
                              "link":"Krish naik.png"
                           },
                           "description":"Having 10+ years of experience in Data Science and Analytics with product architecture design and delivery. Worked in various product and service based Company. Having an experience of 5+ years in educating people and helping them to make a career transition."
                        },
                        {
                           "_id":"619370a59db36f163876b413",
                           "name":"Sudhanshu Kumar",
                           "social":{
                              "linkedin":"https://www.linkedin.com/in/-sudhanshu-kumar/",
                              "youtube":"https://www.youtube.com/c/sudhanshukumarall"
                           },
                           "img":{
                              "source":"bucket",
                              "link":"Sudhanshu Kumar.png"
                           },
                           "description":"Having 8+ years of experience in Big data, Data Science and Analytics with product architecture design and delivery. Worked in various product and service based Company. Having an experience of 5+ years in educating people and helping them to make a career transition."
                        },
                        {
                           "_id":"6222165b760e3ef701f81a6f",
                           "name":"Sunny Savita",
                           "description":"I'm an AI enthusiast, graduate in Computer science and engineering. Currently working with iNeuron.ai as a Data Scientist and having 2+ years of experience. I have skills in big data, machine learning, computer vision, Natural language processing. My expertise also includes project design development and implementation with AIOps tools. ",
                           "img":{
                              "source":"bucket",
                              "link":"6222165b760e3ef701f81a6f.jpg"
                           }
                        }
                     ],
                     "courseInOneNeuron":{
                        "bundleName":"Tech Neuron",
                        "bundleId":"6187abaa15495237705219ee"
                     },
                     "pricing":{
                        "IN":25000,
                        "US":315,
                        "discount":0,
                        "isFree":False
                     }
                  },
                  "Full Stack Data Science Feb'21 Tech Neuron":{
                     "_id":"6389ab0041896db90e99c131",
                     "platformType":"main",
                     "tags":[
                        
                     ],
                     "labPlans":[
                        
                     ],
                     "description":"This is a full stack data science self-paced course with recordings of live mentor-led certification program and a full-time one-year internship provided by iNeuron intelligence private limited, where you will learn all the stack required to work in the data science, data analytics, and big data industries, including machine learning operations and cloud infrastructure, as well as real-time industry project and product development with the iNeuron product development team, and you will contribute on various levels.",
                     "mode":"self-paced",
                     "seo":{
                        "keywords":"Full Stack Data Science Feb'21 Tech Neuron"
                     },
                     "batches":[
                        
                     ],
                     "createdAt":"2022-12-02T07:36:37.102Z",
                     "img":"6389ab0041896db90e99c131.jpg",
                     "categoryId":"62cd959d53f5fe14766b9ae5",
                     "classTimings":{
                        
                     },
                     "courseMeta":[
                        {
                           "instructors":[
                              "6187a900f07f73543ccb695c",
                              "6187a914f07f73543ccb6999",
                              "618929e26e59b248b8c04aa6",
                              "619370a59db36f163876b413",
                              "6222165b760e3ef701f81a6f"
                           ],
                           "overview":{
                              "learn":[
                                 "Python",
                                 "Stats",
                                 "Machine learning",
                                 "Deep learning",
                                 "Computer vision",
                                 "Natural language processing",
                                 "Data analytics",
                                 "Big data",
                                 "Cloud",
                                 "Architecture",
                                 "Databases"
                              ],
                              "requirements":[
                                 "System with minimum i3 processor or better",
                                 "At least 4 GB of RAM",
                                 "Working internet connection",
                                 "Dedication to learn"
                              ],
                              "features":[
                                 "Full stack Data Science Recorded Lectures",
                                 "One year of internship Anytime",
                                 "56 + hands-on industry real-time projects.",
                                 "500 hours live interactive classes.",
                                 "Lifetime Dashboard access",
                                 "Assignment in all the module"
                              ],
                              "language":"english"
                           }
                        }
                     ],
                     "instructorsDetails":[
                        {
                           "_id":"6187a900f07f73543ccb695c",
                           "name":"Sunny Bhaveen Chandra",
                           "social":{
                              "linkedin":"https://www.linkedin.com/in/c17hawke/",
                              "instagram":"https://www.instagram.com/c17hawke",
                              "facebook":"https://m.facebook.com/c17hawke",
                              "youtube":"https://www.youtube.com/c/c17hawke",
                              "github":"https://github.com/c17hawke"
                           },
                           "description":"Sr. Data Scientist and lecturer at iNeuron.ai with working experience in computer vision, natural language processing and embedded systems. Hands-on experience leveraging machine learning, deep learning, transfer learning models to solve challenging business problems. Also, he has a vast interest in Robotics.",
                           "img":{
                              "source":"bucket",
                              "link":"Sunny iNeuron.png"
                           }
                        },
                        {
                           "_id":"6187a914f07f73543ccb6999",
                           "name":"Sourangshu Pal",
                           "description":"Visual Computing Engineer and instructor at iNeuron.ai having 3 years of diverse experience in the discipline of visual computing with specialization in Deep Learning and Computer Graphics. Loves to analyze, process, and model visual data then interpret the insights to create actionable plans for solving challenging business problems.",
                           "social":{
                              "linkedin":"https://www.linkedin.com/in/sourangshu-pal-0774b212a/",
                              "github":"https://github.com/sourangshupal"
                           },
                           "img":{
                              "source":"bucket",
                              "link":"Sourangshu Pal.png"
                           }
                        },
                        {
                           "_id":"618929e26e59b248b8c04aa6",
                           "name":"krish naik",
                           "social":{
                              "linkedin":"https://www.linkedin.com/in/naikkrish/",
                              "instagram":"https://www.instagram.com/krishnaik06",
                              "facebook":"https://www.facebook.com/krishnaik06",
                              "youtube":"https://www.youtube.com/user/krishnaik06",
                              "github":"https://github.com/krishnaik06"
                           },
                           "img":{
                              "source":"bucket",
                              "link":"Krish naik.png"
                           },
                           "description":"Having 10+ years of experience in Data Science and Analytics with product architecture design and delivery. Worked in various product and service based Company. Having an experience of 5+ years in educating people and helping them to make a career transition."
                        },
                        {
                           "_id":"619370a59db36f163876b413",
                           "name":"Sudhanshu Kumar",
                           "social":{
                              "linkedin":"https://www.linkedin.com/in/-sudhanshu-kumar/",
                              "youtube":"https://www.youtube.com/c/sudhanshukumarall"
                           },
                           "img":{
                              "source":"bucket",
                              "link":"Sudhanshu Kumar.png"
                           },
                           "description":"Having 8+ years of experience in Big data, Data Science and Analytics with product architecture design and delivery. Worked in various product and service based Company. Having an experience of 5+ years in educating people and helping them to make a career transition."
                        },
                        {
                           "_id":"6222165b760e3ef701f81a6f",
                           "name":"Sunny Savita",
                           "description":"I'm an AI enthusiast, graduate in Computer science and engineering. Currently working with iNeuron.ai as a Data Scientist and having 2+ years of experience. I have skills in big data, machine learning, computer vision, Natural language processing. My expertise also includes project design development and implementation with AIOps tools. ",
                           "img":{
                              "source":"bucket",
                              "link":"6222165b760e3ef701f81a6f.jpg"
                           }
                        }
                     ],
                     "courseInOneNeuron":{
                        "bundleName":"Tech Neuron",
                        "bundleId":"6187abaa15495237705219ee"
                     },
                     "pricing":{
                        "IN":25000,
                        "US":315,
                        "discount":0,
                        "isFree":False
                     }
                  },
                  "Machine Learning Bootcamp Tech Neuron":{
                     "_id":"637f220858a1eef0aa0954cf",
                     "platformType":"main",
                     "tags":[
                        
                     ],
                     "labPlans":[
                        
                     ],
                     "description":"In this Machine Learning Bootcamp you will learn technologies like Python, API, database, statistics, ML algorithms, deployment of ML models in various cloud platforms, and all machine learning algorithms. You will also learn about chatbots like Dialogflow, Amazon Lex, Azure Luis \u0026 RASA NLU. 15+ live projects are included to make your journey interesting from Zero to ML Engineer.",
                     "mode":"self-paced",
                     "seo":{
                        "keywords":"Machine Learning Bootcamp Tech Neuron"
                     },
                     "batches":[
                        
                     ],
                     "createdAt":"2022-11-24T07:49:35.657Z",
                     "img":"637f220858a1eef0aa0954cf.jpg",
                     "categoryId":"62cd960b53f5fec5156b9aeb",
                     "classTimings":{
                        "doubtClearing":"11PM - 12AM IST Tuesday \u0026 Thursday",
                        "startDate":"29th Nov'2022",
                        "timings":"8 - 11PM IST Tuesday \u0026 Thursday"
                     },
                     "courseMeta":[
                        {
                           "instructors":[
                              "618929e26e59b248b8c04aa6",
                              "6222165b760e3ef701f81a6f"
                           ],
                           "overview":{
                              "learn":[
                                 "Python",
                                 "APIs",
                                 "Databases",
                                 "Python projects",
                                 "Numpy",
                                 "Pandas",
                                 "Visualizations",
                                 "Stats",
                                 "Supervised Machine learning Algorithms",
                                 "Unsupervised Machine learning Algorithms",
                                 "Dimensionality Reduction",
                                 "Machine Learning Projects",
                                 "Deep learning",
                                 "PowerBI",
                                 "Tableau",
                                 "Chatbots"
                              ],
                              "requirements":[
                                 "Dedication",
                                 "Laptop with internet connectivity"
                              ],
                              "features":[
                                 "Machine Learning in Depth",
                                 "CI/CD pipeline for ML",
                                 "End to End Model Deployment in Azure, GCP \u0026 AWS",
                                 "Time Series end-to-end implementation in ML",
                                 "20 + hands-on industry real-time projects",
                                 "Power BI and Tableau self-placed course",
                                 "150+ hours live interactive classes",
                                 "Doubt clearing session after the live classes",
                                 "Doubt clearing one-to-one",
                                 "Doubt clearing through mail and support team",
                                 "Assignment in all the modules",
                                 "20+ use cases of Machine learning",
                                 "Live project with real-time implementation",
                                 "Online Instructor-led learning"
                              ],
                              "language":"english"
                           }
                        }
                     ],
                     "instructorsDetails":[
                        {
                           "_id":"618929e26e59b248b8c04aa6",
                           "name":"krish naik",
                           "social":{
                              "linkedin":"https://www.linkedin.com/in/naikkrish/",
                              "instagram":"https://www.instagram.com/krishnaik06",
                              "facebook":"https://www.facebook.com/krishnaik06",
                              "youtube":"https://www.youtube.com/user/krishnaik06",
                              "github":"https://github.com/krishnaik06"
                           },
                           "img":{
                              "source":"bucket",
                              "link":"Krish naik.png"
                           },
                           "description":"Having 10+ years of experience in Data Science and Analytics with product architecture design and delivery. Worked in various product and service based Company. Having an experience of 5+ years in educating people and helping them to make a career transition."
                        },
                        {
                           "_id":"6222165b760e3ef701f81a6f",
                           "name":"Sunny Savita",
                           "description":"I'm an AI enthusiast, graduate in Computer science and engineering. Currently working with iNeuron.ai as a Data Scientist and having 2+ years of experience. I have skills in big data, machine learning, computer vision, Natural language processing. My expertise also includes project design development and implementation with AIOps tools. ",
                           "img":{
                              "source":"bucket",
                              "link":"6222165b760e3ef701f81a6f.jpg"
                           }
                        }
                     ],
                     "courseInOneNeuron":{
                        "bundleName":"Tech Neuron",
                        "bundleId":"6187abaa15495237705219ee"
                     },
                     "pricing":{
                        "IN":25000,
                        "US":315,
                        "discount":0,
                        "isFree":False
                     }
                  },
}


import pandas as pd

df = pd.DataFrame(details)

df = df.transpose()

df_d = df[df['categoryId'] == '62cd959d53f5fe14766b9ae5']

df_d[['instructorsDetails']]
#df_d.index.values
# Out:
#                                                                            instructorsDetails
# Full Stack Data Science Nov'21 Tech Neuron  [{'_id': '618929e26e59b248b8c04aa6', 'name': '...
# Full Stack Data Science Feb'21 Tech Neuron  [{'_id': '6187a900f07f73543ccb695c', 'name': '...

# %%
dd = pd.DataFrame(df_d[['instructorsDetails']])

for i in dd:
    print(type(i))
# Out:
# <class 'str'>

# %%
more_data = pd.DataFrame(
   {"Full Stack Data Science Nov'21 Tech Neuron":{
      
                     "_id":"6389b7ff41896d32c199d378",
                     "platformType":"main",
                     "tags":[
                        
                     ],
                     "labPlans":[
                        
                     ],
                     "description":"This is a full stack data science self-paced course with recordings of  live mentor-led classes and a full-time one-year internship provided by iNeuron intelligence private limited, where you will learn all the stack required to work in the data science, data analytics, and big data industries, including machine learning operations and cloud infrastructure, as well as real-time industry project and product development with the iNeuron product development team, and you will contribute on various levels.",
                     "mode":"self-paced",
                     "seo":{
                        "keywords":"Full Stack Data Science Nov'21 Tech Neuron"
                     },
                     "batches":[
                        
                     ],
                     "createdAt":"2022-12-02T08:32:02.162Z",
                     "img":"6389b7ff41896d32c199d378.jpg",
                     "categoryId":"62cd959d53f5fe14766b9ae5",
                     "classTimings":{
                        
                     },
                     "courseMeta":[
                        {
                           "instructors":[
                              "619370a59db36f163876b413",
                              "618929e26e59b248b8c04aa6",
                              "6222165b760e3ef701f81a6f"
                           ],
                           "overview":{
                              "learn":[
                                 "Python",
                                 "Stats",
                                 "Machine learning",
                                 "Deep learning",
                                 "Computer vision",
                                 "Natural language processing",
                                 "Data analytics",
                                 "Big data",
                                 "Architecture",
                                 "Databases"
                              ],
                              "requirements":[
                                 "System with minimum i3 processor or better",
                                 "At least 4 GB of RAM",
                                 "Working internet connection",
                                 "Dedication to learn"
                              ],
                              "features":[
                                 "Full stack Data Science Recorded Lectures",
                                 "One year of internship Anytime",
                                 "Online Instructor-led learning: Live teaching by instructors",
                                 "56 + hands-on industry real-time projects.",
                                 "500 hours live interactive classes.",
                                 "Lifetime Dashboard access",
                                 "Assignment in all the module"
                              ],
                              "language":"english"
                           }
                        }
                     ],
                     "instructorsDetails":[
                        {
                           "_id":"618929e26e59b248b8c04aa6",
                           "name":"krish naik",
                           "social":{
                              "linkedin":"https://www.linkedin.com/in/naikkrish/",
                              "instagram":"https://www.instagram.com/krishnaik06",
                              "facebook":"https://www.facebook.com/krishnaik06",
                              "youtube":"https://www.youtube.com/user/krishnaik06",
                              "github":"https://github.com/krishnaik06"
                           },
                           "img":{
                              "source":"bucket",
                              "link":"Krish naik.png"
                           },
                           "description":"Having 10+ years of experience in Data Science and Analytics with product architecture design and delivery. Worked in various product and service based Company. Having an experience of 5+ years in educating people and helping them to make a career transition."
                        },
                        {
                           "_id":"619370a59db36f163876b413",
                           "name":"Sudhanshu Kumar",
                           "social":{
                              "linkedin":"https://www.linkedin.com/in/-sudhanshu-kumar/",
                              "youtube":"https://www.youtube.com/c/sudhanshukumarall"
                           },
                           "img":{
                              "source":"bucket",
                              "link":"Sudhanshu Kumar.png"
                           },
                           "description":"Having 8+ years of experience in Big data, Data Science and Analytics with product architecture design and delivery. Worked in various product and service based Company. Having an experience of 5+ years in educating people and helping them to make a career transition."
                        },
                        {
                           "_id":"6222165b760e3ef701f81a6f",
                           "name":"Sunny Savita",
                           "description":"I'm an AI enthusiast, graduate in Computer science and engineering. Currently working with iNeuron.ai as a Data Scientist and having 2+ years of experience. I have skills in big data, machine learning, computer vision, Natural language processing. My expertise also includes project design development and implementation with AIOps tools. ",
                           "img":{
                              "source":"bucket",
                              "link":"6222165b760e3ef701f81a6f.jpg"
                           }
                        }
                     ],
                     "courseInOneNeuron":{
                        "bundleName":"Tech Neuron",
                        "bundleId":"6187abaa15495237705219ee"
                     },
                     "pricing":{
                        "IN":25000,
                        "US":315,
                        "discount":0,
                        "isFree":False
                     }
                  }})

# %%
more_data
# Out:
#                            Full Stack Data Science Nov'21 Tech Neuron
# _id                                          6389b7ff41896d32c199d378
# batches                                                            []
# categoryId                                   62cd959d53f5fe14766b9ae5
# classTimings                                                       {}
# courseInOneNeuron   {'bundleName': 'Tech Neuron', 'bundleId': '618...
# courseMeta          [{'instructors': ['619370a59db36f163876b413', ...
# createdAt                                    2022-12-02T08:32:02.162Z
# description         This is a full stack data science self-paced c...
# img                                      6389b7ff41896d32c199d378.jpg
# instructorsDetails  [{'_id': '618929e26e59b248b8c04aa6', 'name': '...
# labPlans                                                           []
# mode                                                       self-paced
# ...

# %%
more_data.keys()
# Out:
# Index(['Full Stack Data Science Nov'21 Tech Neuron'], dtype='object')

# %%
for i in more_data['courseMeta'].items():
    print(i)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# f:\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# f:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# f:\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'courseMeta'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
