# %% [markdown]
# Question 9 -
# Write a program to read the data from the following link, perform data analysis and answer the following
# questions
# Note -
# 1. Write code comments wherever required for code understanding
# Link - https://data.wa.gov/api/views/f6w7-q2d2/rows.csv?accessType=DOWNLOAD
# Insights to be drawn -
#
# ● Get all the cars and their types that do not qualify for clean alternative fuel vehicle
# ● Get all TESLA cars with the model year, and model type made in Bothell City.
# ● Get all the cars that have an electric range of more than 100, and were made after
# 2015
# ● Draw plots to show the distribution between city and electric vehicle type

# %%
import pandas as pd

df = pd.read_csv("Electric_Vehicle_Population_Data.csv")

# %%
df.sample(2)
# Out:
#         VIN (1-10)     County     City State  Postal Code  Model Year   Make  \
# 128092  WBY7Z2C58J  Snohomish  Edmonds    WA      98026.0        2018    BMW
# 114681  7SAYGDEE9N   Thurston  Olympia    WA      98501.0        2022  TESLA
#
#           Model           Electric Vehicle Type  \
# 128092       I3  Battery Electric Vehicle (BEV)
# 114681  MODEL Y  Battery Electric Vehicle (BEV)
#
#         Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric Range  \
# 128092            Clean Alternative Fuel Vehicle Eligible             114
# 114681  Eligibility unknown as battery range has not b...               0
#
#         Base MSRP  Legislative District  DOL Vehicle ID  \
# 128092          0                  21.0       474613408
# 114681          0                  35.0       220524335
#
#                    Vehicle Location        Electric Utility  2020 Census Tract
# 128092  POINT (-122.31768 47.87166)  PUGET SOUND ENERGY INC       5.306105e+10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130443 entries, 0 to 130442
# Data columns (total 17 columns):
#  #   Column                                             Non-Null Count   Dtype
# ---  ------                                             --------------   -----
#  0   VIN (1-10)                                         130443 non-null  object
#  1   County                                             130440 non-null  object
#  2   City                                               130440 non-null  object
#  3   State                                              130443 non-null  object
#  4   Postal Code                                        130440 non-null  float64
#  5   Model Year                                         130443 non-null  int64
#  6   Make                                               130443 non-null  object
#  7   Model                                              130221 non-null  object
# ...

# %%
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].unique()
# Out:
# array(['Clean Alternative Fuel Vehicle Eligible',
#        'Not eligible due to low battery range',
#        'Eligibility unknown as battery range has not been researched'],
#       dtype=object)

# %% [markdown]
# ### Get all the cars and their types that do not qualify for clean alternative fuel vehicle

# %%
df[df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'] == "Clean Alternative Fuel Vehicle Eligible"]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 1       JHMZC5F37M    Kitsap        Poulsbo    WA      98370.0        2021
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 3       1N4AZ0CP5D      King        Seattle    WA      98119.0        2013
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# ...            ...       ...            ...   ...          ...         ...
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130429  5UXTA6C03N    Pierce       Puyallup    WA      98375.0        2022
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model                   Electric Vehicle Type  \
# ...

# %% [markdown]
# ### Get all TESLA cars with the model year, and model type made in Bothell City.

# %%
# df[ df['Make']=='TESLA' and df['Electric Range']>=50 ]

df.loc[((df['Make']=='TESLA') & (df['City']=='Bothell')),["Model","Model Year"]]
# Out:
#           Model  Model Year
# 39      MODEL 3        2020
# 217     MODEL 3        2022
# 218     MODEL Y        2022
# 222     MODEL 3        2018
# 292     MODEL X        2017
# ...         ...         ...
# 129778  MODEL 3        2019
# 129954  MODEL 3        2021
# 129976  MODEL S        2014
# 130295  MODEL 3        2022
# 130392  MODEL 3        2018
#
# [2407 rows x 2 columns]

# %% [markdown]
# ### Get all the cars that have an electric range of more than 100, and were made after 2015

# %%
df.loc[((df["Electric Range"]>100) & (df['Model Year']>2015) )]
# Out:
#         VIN (1-10)    County           City State  Postal Code  Model Year  \
# 0       5YJXCAE26J    Yakima         Yakima    WA      98908.0        2018
# 2       5YJ3E1EB0K      King        Seattle    WA      98199.0        2019
# 4       5YJSA1E21H  Thurston          Lacey    WA      98516.0        2017
# 12      5YJ3E1EC7L  Thurston          Lacey    WA      98503.0        2020
# 13      5YJ3E1EB2L  Thurston        Olympia    WA      98516.0        2020
# ...            ...       ...            ...   ...          ...         ...
# 130417  5YJYGDEE5L    Pierce         Tacoma    WA      98444.0        2020
# 130428  1N4AZ1CP0J   Clallam         Sequim    WA      98382.0        2018
# 130432  5YJYGDEEXL      King         Vashon    WA      98070.0        2020
# 130436  5YJ3E1EB0J   Whatcom         Blaine    WA      98230.0        2018
# 130441  5YJXCBE22L    Island  Camano Island    WA      98282.0        2020
#
#           Make    Model           Electric Vehicle Type  \
# ...

# %% [markdown]
# ### Draw plots to show the distribution between city and electric vehicle type

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# sns.catplot(data=df,x='Electric Vehicle Type')
fig = plt.figure(figsize=(35,35)) 
fig_dims = (3, 2)
plt.subplot2grid(fig_dims, (0, 0))

l = df.groupby(['Electric Vehicle Type','City']).size()
l.plot.bar()
# sns.countplot(df['Electric Vehicle Type'])
# sns.countplot(df['City'])
# Out:
# <Axes: xlabel='Electric Vehicle Type,City'>
