# %% [markdown]
# Question 7 -
# Using the data from Question 4, write code to analyze the data and answer the following questions Note -
# 1. Draw plots to demonstrate the analysis for the following questions for better visualizations
# 2. Write code comments wherever required for code understanding
# Insights to be drawn -
# ● Get all the Earth meteorites that fell before the year 2000
#
# ● Get all the earth meteorites co-ordinates who fell before the year 1970
#
# ● Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more
# than 10000kg

# %%
import json
from urllib.request import urlopen
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


url = "https://data.nasa.gov/resource/y77d-th95.json"
response = urlopen(url)

# from url in data to json
data_json = json.loads(response.read())

#converting into datafame
df = pd.DataFrame(data_json)

#trimming unnecessary columns
df = df[["name","id", "nametype","recclass","mass","fall","year","reclat","reclong","geolocation"]]

# %%
df.sample(2)
# Out:
#             name     id nametype recclass  mass  fall  \
# 547        Lixna  14670    Valid       H4  5213  Fell
# 906  Sete Lagoas  23504    Valid       H4   350  Fell
#
#                         year      reclat     reclong  \
# 547  1820-01-01T00:00:00.000   56.000000   26.433330
# 906  1908-01-01T00:00:00.000  -19.466670  -44.216670
#
#                                            geolocation
# 547   {'type': 'Point', 'coordinates': [26.43333, 56]}
# 906  {'type': 'Point', 'coordinates': [-44.21667, -...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   name         1000 non-null   object
#  1   id           1000 non-null   object
#  2   nametype     1000 non-null   object
#  3   recclass     1000 non-null   object
#  4   mass         972 non-null    object
#  5   fall         1000 non-null   object
#  6   year         999 non-null    object
#  7   reclat       988 non-null    object
#  8   reclong      988 non-null    object
#  9   geolocation  988 non-null    object
# dtypes: object(10)
# memory usage: 78.2+ KB

# %%
#● Get all the Earth meteorites that fell before the year 2000
df['date'] = pd.to_datetime(df['year'], errors = 'coerce')
df_2T = df[df['date'].dt.year < 2000]
df_2T
# Out:
#           name     id nametype     recclass    mass  fall  \
# 0       Aachen      1    Valid           L5      21  Fell
# 1       Aarhus      2    Valid           H6     720  Fell
# 2         Abee      6    Valid          EH4  107000  Fell
# 3     Acapulco     10    Valid  Acapulcoite    1914  Fell
# 4      Achiras    370    Valid           L6     780  Fell
# ..         ...    ...      ...          ...     ...   ...
# 994   Timochin  24004    Valid           H5   65500  Fell
# 995   Tirupati  24009    Valid           H6     230  Fell
# 997      Tjabe  24011    Valid           H6   20000  Fell
# 998   Tjerebon  24012    Valid           L5   16500  Fell
# 999  Tomakovka  24019    Valid          LL6     600  Fell
#
#                         year      reclat      reclong  \
# 0    1880-01-01T00:00:00.000   50.775000     6.083330
# 1    1951-01-01T00:00:00.000   56.183330    10.233330
# 2    1952-01-01T00:00:00.000   54.216670  -113.000000
# 3    1976-01-01T00:00:00.000   16.883330   -99.900000
# 4    1902-01-01T00:00:00.000  -33.166670   -64.950000
# ..                       ...         ...          ...
# 994  1807-01-01T00:00:00.000   54.500000    35.200000
# 995  1934-01-01T00:00:00.000   13.633330    79.416670
# 997  1869-01-01T00:00:00.000   -7.083330   111.533330
# 998  1922-01-01T00:00:00.000   -6.666670   106.583330
# 999  1905-01-01T00:00:00.000   47.850000    34.766670
#
#                                            geolocation       date
# 0    {'type': 'Point', 'coordinates': [6.08333, 50.... 1880-01-01
# 1    {'type': 'Point', 'coordinates': [10.23333, 56... 1951-01-01
# 2    {'type': 'Point', 'coordinates': [-113, 54.216... 1952-01-01
# 3    {'type': 'Point', 'coordinates': [-99.9, 16.88... 1976-01-01
# 4    {'type': 'Point', 'coordinates': [-64.95, -33.... 1902-01-01
# ..                                                 ...        ...
# 994     {'type': 'Point', 'coordinates': [35.2, 54.5]} 1807-01-01
# 995  {'type': 'Point', 'coordinates': [79.41667, 13... 1934-01-01
# 997  {'type': 'Point', 'coordinates': [111.53333, -... 1869-01-01
# 998  {'type': 'Point', 'coordinates': [106.58333, -... 1922-01-01
# 999  {'type': 'Point', 'coordinates': [34.76667, 47... 1905-01-01
#
# [912 rows x 11 columns]

# %%
#Get all the Earth meteorites that fell before the year 2000

sns.countplot(x='fall', data=df[df['date'].dt.year < 2000])
sns.countplot(x='fall', data=df[df['date'].dt.year > 2000])
plt.show()

# %%
#Get all the earth meteorites co-ordinates who fell before the year 1970

# filtering records before the year 1970
dd = df[df['date'].dt.year < 1970]

# converting geolocation volumn into series and than acessign coordinates values..
dd['cordinates'] = dd['geolocation'].apply(pd.Series)['coordinates']#['type'])

dd.sample(3)

# dd[']
# Out:
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_20396\987589613.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dd['cordinates'] = dd['geolocation'].apply(pd.Series)['coordinates']#['type'])
#            name     id nametype     recclass  mass  fall  \
# 706     Norfork  16994    Valid  Iron, IIIAB  1050  Fell
# 280    Ellemeet  10019    Valid    Diogenite  1470  Fell
# 666  Nadiabondi  16889    Valid           H5  8165  Fell
#
#                         year     reclat     reclong  \
# 706  1918-01-01T00:00:00.000  36.216670  -92.266670
# 280  1925-01-01T00:00:00.000  51.750000    4.000000
# 666  1956-01-01T00:00:00.000  12.000000    1.000000
#
#                                            geolocation       date  \
# 706  {'type': 'Point', 'coordinates': [-92.26667, 3... 1918-01-01
# 280       {'type': 'Point', 'coordinates': [4, 51.75]} 1925-01-01
# 666          {'type': 'Point', 'coordinates': [1, 12]} 1956-01-01
#
#                 cordinates
# 706  [-92.26667, 36.21667]
# 280             [4, 51.75]
# 666                [1, 12]

# %%
dd['longitute']=dd['cordinates'].apply(pd.Series)[0]
dd['latitude']=dd['cordinates'].apply(pd.Series)[1]
# Out:
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_20396\2614055954.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dd['longitute']=dd['cordinates'].apply(pd.Series)[0]
# C:\Users\Darshi\AppData\Local\Temp\ipykernel_20396\2614055954.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dd['latitude']=dd['cordinates'].apply(pd.Series)[1]

# %%
dd.sample(3)
# Out:
#                 name     id nametype recclass   mass  fall  \
# 404  Itapicuru-Mirim  12056    Valid       H5   2024  Fell
# 676            Naoki  16908    Valid       H6  17000  Fell
# 500           Krymka  12364    Valid    LL3.2  50000  Fell
#
#                         year     reclat     reclong  \
# 404  1879-01-01T00:00:00.000  -3.400000  -44.333330
# 676  1928-01-01T00:00:00.000  19.250000   77.000000
# 500  1946-01-01T00:00:00.000  47.833330   30.766670
#
#                                            geolocation       date  \
# 404  {'type': 'Point', 'coordinates': [-44.33333, -... 1879-01-01
# 676      {'type': 'Point', 'coordinates': [77, 19.25]} 1928-01-01
# 500  {'type': 'Point', 'coordinates': [30.76667, 47... 1946-01-01
#
#                cordinates  longitute  latitude
# 404     [-44.33333, -3.4]  -44.33333  -3.40000
# 676           [77, 19.25]   77.00000  19.25000
# 500  [30.76667, 47.83333]   30.76667  47.83333

# %%
#Get all the earth meteorites co-ordinates who fell before the year 1970
import pandas as pd
from shapely.geometry import Point
import geopandas as gpd
from geopandas import GeoDataFrame

geometry = [Point(xy) for xy in zip(dd['longitute'], dd['latitude'])]
gdf = GeoDataFrame(dd, geometry=geometry)   

#this is a simple map that goes with geopandas
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
gdf.plot(ax=world.plot(figsize=(10, 6)), marker='o', color='red', markersize=15);

# %%
# Assuming that the mass of the earth meteorites was in kg, get all those whose mass was more than 10000kg

#need to covert mass column into float first..
df['mass'] = df['mass'].fillna(0).astype(float)

df[df['mass'] > 10000]
# Out:
#            name     id nametype   recclass      mass  fall  \
# 2          Abee      6    Valid        EH4  107000.0  Fell
# 7          Agen    392    Valid         H5   30000.0  Fell
# 11          Aïr    424    Valid         L6   24000.0  Fell
# 16      Akyumak    433    Valid  Iron, IVA   50000.0  Fell
# 27   Alfianello    466    Valid         L6  228000.0  Fell
# ..          ...    ...      ...        ...       ...   ...
# 991   Tieschitz  23989    Valid     H/L3.6   28000.0  Fell
# 992      Tilden  23998    Valid         L6   74800.0  Fell
# 994    Timochin  24004    Valid         H5   65500.0  Fell
# 997       Tjabe  24011    Valid         H6   20000.0  Fell
# 998    Tjerebon  24012    Valid         L5   16500.0  Fell
#
#                         year     reclat      reclong  \
# 2    1952-01-01T00:00:00.000  54.216670  -113.000000
# 7    1814-01-01T00:00:00.000  44.216670     0.616670
# 11   1925-01-01T00:00:00.000  19.083330     8.383330
# 16   1981-01-01T00:00:00.000  39.916670    42.816670
# 27   1883-01-01T00:00:00.000  45.266670    10.150000
# ..                       ...        ...          ...
# 991  1878-01-01T00:00:00.000  49.600000    17.116670
# 992  1927-01-01T00:00:00.000  38.200000   -89.683330
# 994  1807-01-01T00:00:00.000  54.500000    35.200000
# 997  1869-01-01T00:00:00.000  -7.083330   111.533330
# 998  1922-01-01T00:00:00.000  -6.666670   106.583330
#
#                                            geolocation       date
# 2    {'type': 'Point', 'coordinates': [-113, 54.216... 1952-01-01
# 7    {'type': 'Point', 'coordinates': [0.61667, 44.... 1814-01-01
# 11   {'type': 'Point', 'coordinates': [8.38333, 19.... 1925-01-01
# 16   {'type': 'Point', 'coordinates': [42.81667, 39... 1981-01-01
# 27   {'type': 'Point', 'coordinates': [10.15, 45.26... 1883-01-01
# ..                                                 ...        ...
# 991  {'type': 'Point', 'coordinates': [17.11667, 49... 1878-01-01
# 992  {'type': 'Point', 'coordinates': [-89.68333, 3... 1927-01-01
# 994     {'type': 'Point', 'coordinates': [35.2, 54.5]} 1807-01-01
# 997  {'type': 'Point', 'coordinates': [111.53333, -... 1869-01-01
# 998  {'type': 'Point', 'coordinates': [106.58333, -... 1922-01-01
#
# [243 rows x 11 columns]
