# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/deppsort_yolo
# Out:
# /content/drive/MyDrive/Colab_Notebooks/deppsort_yolo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Colab_Notebooks/deppsort_yolo

# %%
# !git clone https://github.com/ZQPei/deep_sort_pytorch.git
# Out:
# Cloning into 'deep_sort_pytorch'...
# remote: Enumerating objects: 732, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 732 (delta 8), reused 5 (delta 0), pack-reused 717
# Receiving objects: 100% (732/732), 23.72 MiB | 15.43 MiB/s, done.
# Resolving deltas: 100% (355/355), done.

# %%
# %cd deep_sort_pytorch/
# Out:
# /content/drive/MyDrive/Colab_Notebooks/deppsort_yolo/deep_sort_pytorch

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.9/69.9 kB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 15.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.4/5.4 MB 85.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (pyproject.toml) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
pwd
# Out:
# '/content/drive/MyDrive/Colab_Notebooks/deppsort_yolo/deep_sort_pytorch'

# %%
# %cd /content/drive/MyDrive/Colab_Notebooks/deppsort_yolo/deep_sort_pytorch/deep_sort/deep
# Out:
# /content/drive/MyDrive/Colab_Notebooks/deppsort_yolo/deep_sort_pytorch/deep_sort/deep

# %%
# %cp -r /content/drive/MyDrive/Colab_Notebooks/deppsort_yolo/data /content/drive/MyDrive/Colab_Notebooks/deppsort_yolo/deep_sort_pytorch/deep_sort/deep

# %%
# !python train.py
# Out:
# Epoch : 1
# Testing ...
# [progress:100.0%]time:0.21s Loss:0.00000 Correct:22/22 Acc:100.000%
# Saving parameters to checkpoint/ckpt.t7
#
# Epoch : 2
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 3
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 4
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 5
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 6
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 7
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 8
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 9
# Testing ...
# [progress:100.0%]time:0.05s Loss:0.00000 Correct:22/22 Acc:100.000%
#
# Epoch : 10
# Testing ...
# ...
