# %%
pip install cassandra-driver #install driver for casandrapip install dse-driver
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Invalid requirement: '#install'

# %%
python -c 'import cassandra; print (cassandra.__version__)' #test installations

# %%
import dse

# %%
print(dse.__version__)
# Out:
# 2.11.1

# %%
#conncet_Database.py

from cassandra.cluster import Cluster
from cassandra.auth import PlainTextAuthProvider
import json

# This secure connect bundle is autogenerated when you download your SCB, 
# if yours is different update the file name below
cloud_config= {
  'secure_connect_bundle': './db/secure-connect-db-census-income.zip'
}

# This token JSON file is autogenerated when you download your token, 
# if yours is different update the file name below
with open("./db/db_census_income-token.json") as f:
    secrets = json.load(f)

CLIENT_ID = secrets["clientId"]
CLIENT_SECRET = secrets["secret"]

auth_provider = PlainTextAuthProvider(CLIENT_ID, CLIENT_SECRET)
cluster = Cluster(cloud=cloud_config, auth_provider=auth_provider)
session = cluster.connect('keyspace_census')

row = session.execute("select release_version from system.local").one()
if row:
  print(row[0])
else:
  print("An error occurred.")
# Out:
# 4.0.0.6816

# %%
# Create a table.
session.execute('CREATE TABLE census_income_tbl (id int, name text, age int, PRIMARY KEY (id))')

# %%
query = "SELECT * FROM census_income_tbl;"

results = session.execute(query)

for row in results:
  print(row)

# %%
session.execute(
    """
    INSERT INTO user_test (id,name, age)
    VALUES (%s, %s, %s)
    """,
    (1,"John O'Reilly", 42)
)

# %%
session.execute(
    """
    INSERT INTO user_test (id,name, age)
    VALUES (%s, %s, %s)
    """,
    (2,"abc", 32)
)

# %%
session.execute(
    """
    INSERT INTO user_test (id,name, age)
    VALUES (%s, %s, %s)
    """,
    (3,"AGH", 47)
)

# %%
query = "SELECT * FROM user_test;"

results = session.execute(query)

for row in results:
  print(row)
  print(row.id)
# Out:
# Row(id=1, age=42, name="John O'Reilly")
# 1
# Row(id=2, age=32, name='abc')
# 2
# Row(id=3, age=47, name='AGH')
# 3

# %%
session.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9080\1288808572.py in <module>
# ----> 1 session.close()
#
# AttributeError: 'Session' object has no attribute 'close'

# %%
# Close the Session object.
session.shutdown()

# Close the Cluster object.
cluster.shutdown()
